# %%
import pyautogui
button7location = pyautogui.locateOnScreen('listagem.png', grayscale=True)
print(button7location)
# Out:
# Box(left=np.int64(1142), top=np.int64(755), width=79, height=30)

# %%
import pyautogui

def error():
    print("Não encontrado.")
    pyautogui.screenshot('erro.png')

botao = pyautogui.locateCenterOnScreen("listagem.png", confidence=0.8)
print(botao)
if botao:
    pyautogui.click(botao)
else:
    pyautogui.screenshot(region=(botao))
# Out:
# None
