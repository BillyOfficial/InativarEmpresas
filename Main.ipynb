# %%
'''Cala a boca ai pylint, eu sei o que eu to fazendo!'''

from time import sleep
import pyautogui
import pandas as pd

# Ler planilha
planilha = pd.read_excel(r'Relatório\Relação de Empresas por Franquia.xlsx')
Base_codigo = planilha.iloc[:, 0].dropna().astype(int).tolist()

# Listas de imagens
home = ['Home1.png', 'HomenotCF.png']
ativo = ['Ativowhite.png', 'Ativoblack.png']
inativo = ['Inativowhite.png', 'Inativoblack.png', 'InativoblackCF.png']

def puxar(lista, conf=0.8):
    for img in lista:
        try:
            pos = pyautogui.locateOnScreen(img, confidence=conf)
            if pos:
                return pos
        except:
            pass
    return None

# ---------------------------------------------------------------------
# 1) PRIMEIRO: ir para o Home (única coisa que faz sentido procurar agora)
# ---------------------------------------------------------------------

print("Procurando botão Home...")
painel_inicial = puxar(home)

if not painel_inicial:
    print("Erro: Não achei o botão Home na tela!")
    exit()

pyautogui.click(painel_inicial)
sleep(2)

print(f"\nProcessando empresa: {Base_codigo[0]}")

# ---------------------------------------------------------------------
# 2) ABRIR BUSCA E COMEÇAR O PROCESSO
# ---------------------------------------------------------------------

pyautogui.press('f8')
sleep(4)

# escrever código
pyautogui.write(str(Base_codigo[0]))
sleep(2)

pyautogui.click('Dados da empresa2.png')
sleep(4)

for codigo in Base_codigo:

    empresa_ativa = puxar(ativo)
    empresa_inativa = puxar(inativo)

    if empresa_ativa:
        print(f"{codigo} -> Empresa Ativa! Inativando...")
        pyautogui.click(empresa_ativa)
        sleep(2)
        pyautogui.click('Inativar Empresa.png')
        sleep(2)
        pyautogui.click('Gravar.png')
        sleep(4)

    elif empresa_inativa:
        print(f"{codigo} -> Já está inativa.")

    else:
        print(f"{codigo} -> Situação desconhecida: não achei ativo nem inativo.")

    # Ir para editar para a próxima empresa
    editar = ['Editar.png', 'Editar2.png', 'Editar3.png']
    editar_empresa = puxar(editar)

    pyautogui.click(editar_empresa)
    sleep(4)
    pyautogui.write(str(codigo))
    sleep(1)
    pyautogui.press('tab')
    sleep(2)
# Out:
# <>:6: SyntaxWarning: invalid escape sequence '\R'
# <>:6: SyntaxWarning: invalid escape sequence '\R'
# C:\Users\Usuário\AppData\Local\Temp\ipykernel_12208\1330511301.py:6: SyntaxWarning: invalid escape sequence '\R'
#   planilha = pd.read_excel('Relatório\Relação de Empresas por Franquia.xlsx')
# 2506 -> Outro situação informada.

# %%
from time import sleep
import pyautogui
import pandas as pd

# Ler planilha
planilha = pd.read_excel(r'Relatório\Relação de Empresas por Franquia.xlsx')
Base_codigo = planilha.iloc[:, 0].dropna().astype(int).tolist()

# Listas de imagens
home = ['Home1.png', 'HomenotCF.png']
ativo = ['Ativowhite.png', 'Ativoblack.png']
inativo = ['Inativowhite.png', 'Inativoblack.png', 'InativoblackCF.png']
editar = ['Editar.png', 'Editar2.png']


def puxar(lista, conf=0.8):
    """Procura a primeira imagem na tela."""
    for img in lista:
        pos = pyautogui.locateOnScreen(img, confidence=conf)
        if pos:
            return pos
    return None


for codigo in Base_codigo:

    print(f"\nProcessando empresa: {codigo}")

    # escrever código
    #pyautogui.write(str(codigo))
    #sleep(2)

    #pyautogui.click('Dados da empresa2.png')
    #sleep(4)

    # AGORA sim tentamos identificar se está ativa ou inativa
    empresa_ativa = puxar(ativo)
    empresa_inativa = puxar(inativo)

    if empresa_ativa:
        print(f"{codigo} -> Empresa Ativa! Inativando...")
        pyautogui.click('Ativoblack.png')
        sleep(2)
        pyautogui.click('Inativar Empresa.png')
        sleep(2)
        pyautogui.click('Gravar.png')
        sleep(4)

    elif empresa_inativa:
        print(f"{codigo} -> Já está inativa.")

    else:
        print(f"{codigo} -> Situação desconhecida: não achei ativo nem inativo.")

    # Ir para editar para a próxima empresa
    pos_editar = puxar(editar)

    if not pos_editar:
        print("Erro: Não achei botão EDITAR na tela.")
        exit()

    pyautogui.click(pos_editar)
    sleep(3)
# Out:
# Processando empresa: 2506
# 2506 -> Já está inativa.
#
# Processando empresa: 2615
# 2615 -> Empresa Ativa! Inativando...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 42
#      40 if empresa_ativa:
#      41     print(f"{codigo} -> Empresa Ativa! Inativando...")
# ---> 42     pyautogui.click('Ativoblack.png')
#      43     sleep(2)
#      44     pyautogui.click('Inativar Empresa.png')
#
# File c:\Users\Usuário\AppData\Local\Programs\Python\Python313\Lib\site-packages\pyautogui\__init__.py:594, in _genericPyAutoGUIChecks.<locals>.wrapper(*args, **kwargs)
#     591 @functools.wraps(wrappedFunction)
#     592 def wrapper(*args, **kwargs):
#     593     failSafeCheck()
# --> 594     returnVal = wrappedFunction(*args, **kwargs)
#     595     _handlePause(kwargs.get("_pause", True))
#     596     return returnVal
#
# File c:\Users\Usuário\AppData\Local\Programs\Python\Python313\Lib\site-packages\pyautogui\__init__.py:985, in click(x, y, clicks, interval, button, duration, tween, logScreenshot, _pause)
#     983 # TODO: I'm leaving buttons 4, 5, 6, and 7 undocumented for now. I need to understand how they work.
#     984 button = _normalizeButton(button)
# --> 985 x, y = _normalizeXYArgs(x, y)
#     987 # Move the mouse cursor to the x, y coordinate:
#     988 _mouseMoveDrag("move", x, y, 0, 0, duration, tween)
#
# TypeError: cannot unpack non-iterable NoneType object

# %%
from time import sleep
import pyautogui
import pandas as pd

# Ler planilha
planilha = pd.read_excel(r'Relatório\Relação de Empresas por Franquia.xlsx')
Base_codigo = planilha.iloc[:, 0].dropna().astype(int).tolist()

# Listas de imagens
home = ['Home1.png', 'HomenotCF.png']
ativo = ['Ativowhite.png', 'Ativoblack.png']
inativo = ['Inativowhite.png', 'Inativoblack.png', 'InativoblackCF.png']

def puxar(lista, conf=0.8):
    for img in lista:
        try:
            pos = pyautogui.locateOnScreen(img, confidence=conf)
            if pos:
                return pos
        except:
            pass
    return None

# Ir para editar para a próxima empresa
editar = ['Editar.png', 'Editar2.png', 'Editar3.png']
editar_empresa = puxar(editar)
sleep(4)

# %%
for codigo in Base_codigo:

    empresa_ativa = puxar(ativo)
    empresa_inativa = puxar(inativo)

    if empresa_ativa:
        print(f"{codigo} -> Empresa Ativa! Inativando...")
        pyautogui.click(empresa_ativa)
        sleep(2)
        pyautogui.click('Inativar Empresa.png')
        sleep(2)
        pyautogui.click('Gravar.png')
        sleep(4)

    elif empresa_inativa:
        print(f"{codigo} -> Já está inativa.")

        if pyautogui.locateOnScreen('Inativowhite.png', confidence=0.8):
            pyautogui.click('Cancelar.png')
            sleep(2)
        else:
            continue

    else:
        print(f"{codigo} -> Situação desconhecida: não achei ativo nem inativo.")

    # Ir para editar para a próxima empresa
    editar = ['Editar.png', 'Editar2.png', 'Editar3.png']
    editar_empresa = puxar(editar)

    pyautogui.click(editar_empresa)
    sleep(4)
    pyautogui.write(str(codigo))
    sleep(1)
    pyautogui.press('tab')
    sleep(2)
